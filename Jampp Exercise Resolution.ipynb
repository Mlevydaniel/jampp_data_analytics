# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# #### Import relevant libraries together with the function we want to test

# %%
import random
import pandas as pd
import numpy as np

# import 
from Functions.functions import *
# Out:
# library loaded

# %% [markdown]
# #### To test if the function is working fine, we can try it and check if it is returning the values according to the weights defined

# %%
values = [1, 2, 3]
weights = [0.5, 0.3, 0.2]

# %% [markdown]
# #### Lets see how the original function works

# %%
# Run 50000 times the function
numbers = []
for i in range(50000):
    numbers.append(weighted_random(values, weights))

# Check the distribution of the results
numbers = pd.Series(numbers)
numbers.value_counts(normalize=True)
# Out:
# 1.0    0.833723
# 2.0    0.166277
# dtype: float64

# %% [markdown]
# This is not ok

# %% [markdown]
# #### Now the new function

# %%
# Run 50000 times the function
numbers = []
for i in range(50000):
    numbers.append(new_weighted_random(values, weights))

# Check the distribution of the results
numbers = pd.Series(numbers)
numbers.value_counts(normalize=True)
# Out:
# 1    0.50644
# 2    0.29654
# 3    0.19702
# dtype: float64

# %% [markdown]
# We can see that the values that the function returns is now accurate. The problem was in the came from the acum_weights functions which was not doing well its work. It was adding twice the same value instead of adding the next to the previous one
